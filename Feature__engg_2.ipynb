# %%
## Nominal?one hor encoding

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.DataFrame({'colors':['red','blue','green','red','blue']})

# %%
df
# Out:
#   colors
# 0    red
# 1   blue
# 2  green
# 3    red
# 4   blue

# %%
##crete an instance off one hot encoder
encoder=OneHotEncoder()

#fit the encoder to dataframe and transform the categorical variable
emdoded=encoder.fit_transform(df[['colors']])

# %%
#convert sparce matrix into array
encoder.fit_transform(df[['colors']]).toarray()
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [1., 0., 0.]])

# %%
##Label and odinal encoding
"it is for categories in rank"
"convert into categorical eature to numerical feature"
# Out:
# 'convert into categorical eature to numerical feature'

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
#label encoding endoded the data alphabetically

# %%
df=pd.DataFrame({'colors':['red','blue','green','red','blue']})
df
# Out:
#   colors
# 0    red
# 1   blue
# 2  green
# 3    red
# 4   blue

# %%
#cerate an instance of levelencoder
encoder=LabelEncoder()
encoder.fit_transform(df['colors'])
# Out:
# array([2, 0, 1, 2, 0])

# %%
###ORDINAL ENCODING  ude for rank-wise encoding
import pandas  as pd
from sklearn.preprocessing import OrdinalEncoder
df=pd.DataFrame({
    'size':['small','medium','large','small','large']
})

# %%
##create an instance of the odrdinal encoder
#definr categories
encoder=OrdinalEncoder(categories=[['small','medium','large']])

# %%
encoder.fit_transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.]])

# %%
#
"""

Target Guided Ordinal Encoding
It is a technique used to encode categorical variables based on their relationship with the target variable.
This encoding technique is useful when we have a categorical variable with a large number of unique categories,
and we want to use this variable as a feature in our machine learning model.

In Target Guided Ordinal Encoding, we replace each category in the categorical variable with a numerical value based
 on the mean or median of the target variable for that category. This creates a monotonic relationship between the categorical
  variable and the target variable, which can improve the predictive power of our model.
"""
# Out:
# '\n\nTarget Guided Ordinal Encoding\nIt is a technique used to encode categorical variables based on their relationship with the target variable.\nThis encoding technique is useful when we have a categorical variable with a large number of unique categories,\nand we want to use this variable as a feature in our machine learning model.\n\nIn Target Guided Ordinal Encoding, we replace each category in the categorical variable with a numerical value based\n on the mean or median of the target variable for that category. This creates a monotonic relationship between the categorical\n  variable and the target variable, which can improve the predictive power of our model.\n'

# %%
import pandas as pd
#cerate a sample  dattaframe with categorical variable and target variable
df=pd.DataFrame({
    'city':['New York','London','Paris','Tokyo','New York','Paris'],
    'Price':[200,150,300,250,180,320]
})
df
# Out:
#        city  Price
# 0  New York    200
# 1    London    150
# 2     Paris    300
# 3     Tokyo    250
# 4  New York    180
# 5     Paris    320

# %%
#calclate mean price of each city
df.groupby('city')['Price'].mean()
# Out:
# city
# London      150.0
# New York    190.0
# Paris       310.0
# Tokyo       250.0
# Name: Price, dtype: float64

# %%
Mean_price=df.groupby('city')['Price'].mean().to_dict()
Mean_price
# Out:
# {'London': 150.0, 'New York': 190.0, 'Paris': 310.0, 'Tokyo': 250.0}

# %%
#replqce each city with mean price
#map city with its mean price
df['city_encoded']=df['city'].map(Mean_price)
df
# Out:
#        city  Price  city_encoded
# 0  New York    200         190.0
# 1    London    150         150.0
# 2     Paris    300         310.0
# 3     Tokyo    250         250.0
# 4  New York    180         190.0
# 5     Paris    320         310.0
